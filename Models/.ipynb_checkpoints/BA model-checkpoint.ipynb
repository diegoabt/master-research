# %%
import time

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx

# %% [markdown]
# ### Barabasi Model

# %%
ba=nx.barabasi_albert_graph(10,1,0) #IMPORTANT PART! second input must be 1
nx.draw_networkx(ba, edge_color='k', with_labels=True, alpha=.4, linewidths=0)
plt.axis('off')
plt.show()

# %%
ba=nx.barabasi_albert_graph(15,1,0) #IMPORTANT PART! second input must be 1
nx.draw_networkx(ba, edge_color='k', with_labels=True, alpha=.4, linewidths=0)
plt.axis('off')
plt.show()

# %%
ba=nx.barabasi_albert_graph(20,1,0) #IMPORTANT PART! second input must be 1
nx.draw_networkx(ba, edge_color='k', with_labels=True, alpha=.4, linewidths=0)
plt.axis('off')
plt.show()
