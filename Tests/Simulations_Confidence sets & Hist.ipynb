# %% [markdown]
# ### Simulations: Confidence sets & Hist

# %% [markdown]
# Running the estimator from another notebook and defining the dicts to store the **times**. **SIM=500**

# %%
# %run 'Removing-leaves estimator .ipynb'
import time
import powerlaw

# %%
resultsRL_cs={} #This dict contains all the vrtices found by the rl estimator for different graph sizes
values_rl_cs={} #This dict is created from resultsDC
results_rl_cs_time={}

# %%
graph_size=[100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000,10000]:


for N in graph_size:
    results_rl_cs=[]
    start_time=time.time()
    for i in range(0,500):
        ba=nx.barabasi_albert_graph(N,1)
        rl_cs=rem_cs2(ba)
        results_rl_cs.append([N,rl_cs])
    final_time= -start_time +time.time()
    results_rl_time[str(N)]=final_time
    
    resultsRL_cs[str(N)]=[i[1] for i in results_rl_cs ]
    # %matplotlib inline
    values, bins, _ =plt.hist(resultsRL_cs[str(N)], bins=range(0,N),color='m',normed=True)
    values_rl_cs[str(N)]=list(values)
    plt.ylabel('');
    plt.xlabel('rl cs')
    print N
# Out:
# 3000
# 4000
# 5000
# 10000

# %% [markdown]
# The next part exports the results obtained in the sim

# %%
remleaves_cs_results = open('remleavesSim500CF.txt', 'w')
for i in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000,10000]:
  print>>remleaves_cs_results, str(i),resultsRL_cs[str(i)]
remleaves_cs_results.close()

# %% [markdown]
# This part imports them

# %%
inforl_cs= open("remleavesSim500CF.txt").read().split()
importedrl_cs=[i for i in inforl_cs]
RL_cs={}
j=1
for N in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000,10000]:
    RL_cs[str(N)]=importedrl_cs[j:j+500]
    j=j+501

ll=0
for N in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000,10000]:
    for k in range(len(RL_cs[str(N)])):
        RL_cs[str(N)][k]=RL_cs[str(N)][k][:-1]
        for l in RL_cs[str(N)][k]:
            if l=='[':
                RL_cs[str(N)][k]=RL_cs[str(N)][k][1:]
            if l==']':
                RL[str(N)][k]=RL[str(N)][k]
for N in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000,10000]:
    for k in range(len(RL_cs[str(N)])):
        RL_cs[str(N)][k]=int(RL_cs[str(N)][k])
print RL_cs['100']
# Out:
# [6, 1, 6, 15, 2, 2, 4, 45, 1, 2, 2, 19, 3, 1, 4, 37, 3, 59, 1, 28, 2, 2, 19, 2, 19, 1, 6, 3, 3, 2, 2, 6, 3, 15, 2, 5, 5, 2, 6, 18, 4, 2, 9, 4, 1, 2, 3, 3, 7, 55, 3, 1, 6, 2, 1, 34, 5, 91, 4, 5, 4, 19, 2, 9, 44, 5, 4, 5, 1, 9, 63, 2, 9, 18, 11, 3, 52, 6, 3, 5, 2, 2, 23, 3, 1, 2, 8, 7, 1, 18, 2, 3, 1, 6, 1, 2, 1, 8, 7, 25, 5, 2, 3, 2, 63, 24, 2, 3, 3, 44, 1, 3, 5, 10, 3, 6, 1, 1, 10, 9, 4, 2, 5, 20, 4, 4, 5, 1, 3, 7, 84, 4, 4, 1, 2, 2, 2, 2, 6, 2, 13, 3, 22, 41, 17, 3, 2, 33, 2, 1, 3, 6, 42, 4, 1, 5, 14, 20, 9, 48, 9, 1, 8, 32, 3, 47, 4, 2, 65, 1, 3, 8, 4, 5, 1, 68, 1, 1, 3, 77, 3, 17, 24, 6, 2, 2, 2, 2, 3, 21, 2, 2, 2, 6, 3, 17, 5, 31, 1, 5, 3, 1, 1, 1, 6, 2, 6, 11, 1, 1, 4, 3, 3, 2, 2, 2, 4, 2, 4, 4, 60, 19, 2, 7, 9, 4, 89, 4, 13, 3, 4, 5, 6, 4, 9, 3, 1, 2, 34, 10, 3, 4, 2, 2, 7, 1, 1, 8, 2, 8, 2, 71, 4, 1, 3, 10, 7, 1, 3, 19, 3, 1, 2, 2, 7, 4, 12, 2, 1, 1, 1, 1, 4, 2, 12, 12, 12, 2, 2, 5, 1, 2, 36, 17, 4, 1, 31, 7, 1, 1, 39, 16, 4, 5, 10, 26, 2, 3, 1, 65, 1, 1, 30, 10, 3, 6, 5, 3, 2
# ...

# %% [markdown]
# This part is for computing the histograms

# %%
for N in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000,10000]:
    values, bins, _ =plt.hist(RL[str(N)], bins=range(0,N),color='r',normed=True)
    values_rl_cs[str(N)]=list(values_cs)
    plt.ylabel('');
    plt.xlabel('size of the set when 0 is found')
    plt.show()

# %% [markdown]
# Info about simulation's times

# %%
remleaves_times_cf = open('times_remleavesSim500CF.txt', 'w')
for i in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000,10000]:
  print>>remleaves_times_cf, str(i),results_rl_time_cf[str(i)]
remleaves_times_cf.close()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-12-8d0b98862b52> in <module>()
#       1 remleaves_times_cf = open('times_remleavesSim500CF.txt', 'w')
#       2 for i in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000,10000]:
# ----> 3   print>>remleaves_times_cf, str(i),results_rl_time_cf[str(i)]
#       4 remleaves_times_cf.close()
#
# NameError: name 'results_rl_time_cf' is not defined

# %% [markdown]
# ## Histograms

# %%
ax={}
f, ((ax['1'], ax['2'],ax['3'], ax['4']),(ax['5'],ax['6'],ax['7'],ax['8']),(ax['9'],ax['10'],ax['11'],ax['12']),(ax['13'],ax['14'],ax['15'],ax['16'])) = plt.subplots(4, 4, figsize=(13,13))
i=1
f.suptitle('Confidence sets')
for N in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000]:#,10000]:
    ax[str(i)].title.set_text(str(N))
    values, bins, _ =ax[str(i)].hist(RL_cs[str(N)], bins=range(0,N),color='r',normed=True)
       
    i+=1

f.tight_layout()
f.subplots_adjust(top=0.88)

plt.show()

# %%
pl_RL_cs={}

# %%
for N in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000]:#,10000]:
    values, bins, _ =plt.hist(RL_cs[str(N)], bins=range(0,N),color='b',normed=True)
    fit = powerlaw.Fit(values)
    pl_RL_cs[str(N)]=[fit.power_law.alpha,fit.power_law.xmin]
# Out:
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# /home/diego/anaconda2/lib/python2.7/site-packages/powerlaw.py:686: RuntimeWarning: invalid value encountered in divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# ...

# %%
pl_RL_cs
# Out:
# {'100': [2.1194697434061611, 0.002004008016032064],
#  '1000': [2.548158857051094, 0.002],
#  '1500': [2.773519625102252, 0.002],
#  '200': [2.4741389410926447, 0.002],
#  '2000': [1.8041148688157658, 0.0040000000000000001],
#  '2500': [2.7472764296955314, 0.002],
#  '300': [2.3146314942278181, 0.002],
#  '3000': [2.208305439968925, 0.002],
#  '400': [2.4255928929013715, 0.002],
#  '4000': [1.9104529998434261, 0.0040000000000000001],
#  '500': [1.8203863377582554, 0.0040000000000000001],
#  '5000': [2.6981909911868542, 0.002],
#  '600': [1.9148827935069845, 0.0040000000000000001],
#  '700': [2.284250536637265, 0.002],
#  '800': [2.5713976569165968, 0.002],
#  '900': [1.7722182146666703, 0.0040000000000000001]}

# %%
ax2={}
f2, ((ax2['1'], ax2['2'],ax2['3'], ax2['4']),(ax2['5'],ax2['6'],ax2['7'],ax2['8']),(ax2['9'],ax2['10'],ax2['11'],ax2['12']),(ax2['13'],ax2['14'],ax2['15'],ax2['16'])) = plt.subplots(4, 4, figsize=(13,13))
i=1
f2.suptitle('Confidence sets')
for N in [100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000]:#,10000]:
    ax2[str(i)].title.set_text(str(N))
    values, bins, _ =ax2[str(i)].hist(RL[str(N)], bins=range(0,N),color='r',normed=True)
    v=list(values)
    v2=list(values)
    for j in range(0,len(v)):
        v2[j]=sum(v[:j+1])
    ax2[str(i)].bar(range(len(v)), v2,1,color='r')
    i+=1

f2.tight_layout()
f2.subplots_adjust(top=0.88)

plt.show()

# %% [markdown]
# ### Powerlaw

# %%
values, bins, _ =plt.hist(RL[str(100)], bins=range(0,100),color='r',normed=True)
plt.show()

# %%
import powerlaw
fit = powerlaw.Fit(values)
print fit
# Out:
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# ...

# %%
print fit.power_law.alpha
# Out:
# 2.69819099119

# %%
print fit.power_law.xmin
# Out:
# 0.002

# %%
print fit.power_law.sigma
# Out:
# 0.184194674591

# %%
print fit.distribution_compare('power_law', 'exponential')
# Out:
# (129.73795733845768, 6.5775393405384354e-19)

# %%
powerlaw.plot_pdf(values, color='b') #remove 0.0s ??
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-55-f2e7b2e51d49> in <module>()
# ----> 1 powerlaw.plot_pdf(values, color='b') #remove 0.0s ??
#
# /home/diego/anaconda2/lib/python2.7/site-packages/powerlaw.pyc in plot_pdf(data, ax, linear_bins, **kwargs)
#    1866         The axis to which the plot was made.
#    1867     """
# -> 1868     edges, hist = pdf(data, linear_bins=linear_bins, **kwargs)
#    1869     bin_centers = (edges[1:]+edges[:-1])/2.0
#    1870     if not ax:
#
# /home/diego/anaconda2/lib/python2.7/site-packages/powerlaw.pyc in pdf(data, xmin, xmax, linear_bins, **kwargs)
#    1766         bins = range(int(xmin), int(xmax))
#    1767     else:
# -> 1768         log_min_size = log10(xmin)
#    1769         log_max_size = log10(xmax)
#    1770         number_of_bins = ceil((log_max_size-log_min_size)*10)
#
# ValueError: math domain error

# %% [markdown]
# ### Playing w probabilities and confidence sets

# %% [markdown]
# Using the previous results

# %%
# %matplotlib inline
values100, bins, _ =plt.hist(results_cs2_100, bins=range(0,100),normed=True)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
values=list(values100)
values2=list(values100)
for i in range(0,len(values)):
    values2[i]=sum(values[:i+1])

# %matplotlib inline
plt.bar(range(len(values)), values2,1)

#values, bins, _ =plt.hist(results_cs_100, bins=100,normed=True)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
s=0
for i in values:
    s=s+i
print s
# Out:
# 1.0

# %%
print values2
# Out:
# [0.0, 0.19639278557114229, 0.4028056112224449, 0.56312625250501003, 0.64729458917835669, 0.69338677354709422, 0.72745490981963934, 0.7655310621242486, 0.79358717434869752, 0.81362725450901818, 0.83366733466933884, 0.85370741482965951, 0.86372745490981984, 0.86973947895791603, 0.8717434869739481, 0.8717434869739481, 0.87374749498998017, 0.87575150300601223, 0.87975951903807637, 0.88577154308617256, 0.8897795591182367, 0.89579158316633289, 0.89579158316633289, 0.89779559118236496, 0.90180360721442909, 0.90581162324649322, 0.90781563126252529, 0.90981963927855736, 0.90981963927855736, 0.91182364729458942, 0.91182364729458942, 0.91583166332665356, 0.91983967935871769, 0.92184368737474975, 0.92585170340681389, 0.92785571142284595, 0.92785571142284595, 0.93587174348697422, 0.93787575150300628, 0.93787575150300628, 0.93787575150300628, 0.93987975951903835, 0.94388777555110248, 0.94989979959919868, 0.94989979959919868, 0.95390781563126281, 0.95390781563126281, 0.95390781563126281, 0.95390781
# ...

# %%
i=0
I=0
p=.9
while values2[i]<p:
    i=i+1

print 'stop when',i,'vertices remained to guarantee p>=',
# ...

# %%
i=0
j=0
I=0
p=.9
s=0
while s<p:
    s=s+values[j]
    j=j+1
print 'testing. stop when',j,'vertices remained to guarantee p>=',p

while values2[i]<p:
    i=i+1

print 'stop when',i,'vertices remained to guarantee p>=',p

print 'this is ok because of the indexes'
# Out:
# testing. stop when 31 vertices remained to guarantee p>= 0.9
# stop when 30 vertices remained to guarantee p>= 0.9
# this is ok because of the indexes

# %% [markdown]
# ### Histogram 2000 2

# %%
results_cs2_2000= open("sim500n2000.txt").read().split()
results_cs2_2000=[int(i) for i in results_cs2_2000]

# %%
# %matplotlib inline
values2000, bins, _ =plt.hist(results_cs2_2000, bins=range(0,2000),normed=True)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
values=list(values2000)
values2=list(values2000)
for i in range(0,len(values)):
    values2[i]=sum(values[:i+1])

# %matplotlib inline
plt.bar(range(len(values)), values2,1)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
print len(values)
print len(bins)
# Out:
# 1999
# 2000

# %%
s=0
for i in values:
    s=s+i
print s
# Out:
# 1.0

# %%
print values2
# Out:
# [0.0, 0.154, 0.312, 0.436, 0.54200000000000004, 0.6120000000000001, 0.67400000000000015, 0.7220000000000002, 0.74400000000000022, 0.76400000000000023, 0.79400000000000026, 0.80000000000000027, 0.81200000000000028, 0.82000000000000028, 0.82600000000000029, 0.83200000000000029, 0.83200000000000029, 0.8360000000000003, 0.8400000000000003, 0.8420000000000003, 0.84600000000000031, 0.84800000000000031, 0.85200000000000031, 0.85200000000000031, 0.85200000000000031, 0.85600000000000032, 0.86000000000000032, 0.86400000000000032, 0.87000000000000033, 0.87000000000000033, 0.87000000000000033, 0.87200000000000033, 0.87200000000000033, 0.87200000000000033, 0.87400000000000033, 0.87400000000000033, 0.87800000000000034, 0.88200000000000034, 0.88800000000000034, 0.88800000000000034, 0.89000000000000035, 0.89200000000000035, 0.89400000000000035, 0.89400000000000035, 0.89400000000000035, 0.89800000000000035, 0.90000000000000036, 0.90000000000000036, 0.90000000000000036, 0.90000000000000036, 0.90000000
# ...

# %%
i=0
j=0
I=0
p=.9
s=0
while s<p:
    s=s+values[j]
    j=j+1
print 'testing. stop when',j,'vertices remained to guarantee p>=',p

while values2[i]<p:
    i=i+1

print 'stop when',i,'vertices remained to guarantee p>=',p

print 'this is ok because of the indexes'
# Out:
# testing. stop when 47 vertices remained to guarantee p>= 0.9
# stop when 46 vertices remained to guarantee p>= 0.9
# this is ok because of the indexes

# %% [markdown]
# ### Histogram 2500 2

# %%
results_cs2_2500= open("sim500n2500.txt").read().split()
results_cs2_2500=[int(i) for i in results_cs2_2500]

# %%
# %matplotlib inline
values2500, bins, _ =plt.hist(results_cs2_2500, bins=range(0,2500),normed=True)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
values=list(values2500)
values2=list(values2500)
for i in range(0,len(values)):
    values2[i]=sum(values[:i+1])

# %matplotlib inline
plt.bar(range(len(values)), values2,1)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
print len(values)
print len(bins)
# Out:
# 2499
# 2500

# %%
s=0
for i in values:
    s=s+i
print s
# Out:
# 1.0

# %%
print values2
# Out:
# [0.0, 0.13, 0.312, 0.45999999999999996, 0.56199999999999994, 0.62999999999999989, 0.68399999999999994, 0.71399999999999997, 0.73999999999999999, 0.754, 0.76800000000000002, 0.78200000000000003, 0.78600000000000003, 0.80000000000000004, 0.81000000000000005, 0.81800000000000006, 0.82200000000000006, 0.82600000000000007, 0.82600000000000007, 0.83600000000000008, 0.84000000000000008, 0.85000000000000009, 0.8620000000000001, 0.8680000000000001, 0.8680000000000001, 0.87000000000000011, 0.87200000000000011, 0.87600000000000011, 0.87800000000000011, 0.87800000000000011, 0.88200000000000012, 0.88200000000000012, 0.88600000000000012, 0.88800000000000012, 0.88800000000000012, 0.88800000000000012, 0.88800000000000012, 0.88800000000000012, 0.89000000000000012, 0.89200000000000013, 0.89400000000000013, 0.89600000000000013, 0.89600000000000013, 0.89800000000000013, 0.89800000000000013, 0.90000000000000013, 0.90000000000000013, 0.90000000000000013, 0.90000000000000013, 0.90200000000000014, 0.9060000
# ...

# %%
i=0
j=0
I=0
p=.9
s=0
while s<p:
    s=s+values[j]
    j=j+1
print 'testing. stop when',j,'vertices remained to guarantee p>=',p

while values2[i]<p:
    i=i+1

print 'stop when',i,'vertices remained to guarantee p>=',p

print 'this is ok because of the indexes'
# Out:
# testing. stop when 46 vertices remained to guarantee p>= 0.9
# stop when 45 vertices remained to guarantee p>= 0.9
# this is ok because of the indexes

# %%
3000
# Out:
# 3000

# %% [markdown]
# ### Histogram 3000 2

# %%
results_cs2_3000= open("sim500n3000.txt").read().split()
results_cs2_3000=[int(i) for i in results_cs2_3000]

# %%
# %matplotlib inline
values3000, bins, _ =plt.hist(results_cs2_3000, bins=range(0,3000),normed=True)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
values=list(values3000)
values2=list(values3000)
for i in range(0,len(values)):
    values2[i]=sum(values[:i+1])

# %matplotlib inline
plt.bar(range(len(values)), values2,1)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
print len(values)
print len(bins)
# Out:
# 2999
# 3000

# %%
s=0
for i in values:
    s=s+i
print s
# Out:
# 1.0

# %%
print values2
# Out:
# [0.0, 0.17999999999999999, 0.34199999999999997, 0.44799999999999995, 0.53399999999999992, 0.58999999999999997, 0.63600000000000001, 0.67800000000000005, 0.70600000000000007, 0.72000000000000008, 0.7420000000000001, 0.75800000000000012, 0.77000000000000013, 0.78000000000000014, 0.78800000000000014, 0.79800000000000015, 0.80200000000000016, 0.80200000000000016, 0.81400000000000017, 0.81600000000000017, 0.82000000000000017, 0.82600000000000018, 0.82600000000000018, 0.83200000000000018, 0.83600000000000019, 0.83800000000000019, 0.83800000000000019, 0.84200000000000019, 0.84400000000000019, 0.8460000000000002, 0.8480000000000002, 0.8500000000000002, 0.8520000000000002, 0.8520000000000002, 0.8520000000000002, 0.8540000000000002, 0.86000000000000021, 0.86400000000000021, 0.86600000000000021, 0.86600000000000021, 0.86800000000000022, 0.87400000000000022, 0.87400000000000022, 0.87400000000000022, 0.87600000000000022, 0.87600000000000022, 0.87600000000000022, 0.87800000000000022, 0.88000000000
# ...

# %%
i=0
j=0
I=0
p=.9
s=0
while s<p:
    s=s+values[j]
    j=j+1
print 'testing. stop when',j,'vertices remained to guarantee p>=',p

while values2[i]<p:
    i=i+1

print 'stop when',i,'vertices remained to guarantee p>=',p

print 'this is ok because of the indexes'
# Out:
# testing. stop when 63 vertices remained to guarantee p>= 0.9
# stop when 62 vertices remained to guarantee p>= 0.9
# this is ok because of the indexes

# %% [markdown]
# ### Histogram 4000 2

# %%
results_cs2_4000= open("sim500n4000.txt").read().split()
results_cs2_4000=[int(i) for i in results_cs2_4000]

# %%
# %matplotlib inline
values4000, bins, _ =plt.hist(results_cs2_4000, bins=range(0,4000),normed=True)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
values=list(values4000)
values2=list(values4000)
for i in range(0,len(values)):
    values2[i]=sum(values[:i+1])

# %matplotlib inline
plt.bar(range(len(values)), values2,1)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
print len(values)
print len(bins)
# Out:
# 3999
# 4000

# %%
s=0
for i in values:
    s=s+i
print s
# Out:
# 1.0

# %%
print values2
# Out:
# [0.0, 0.184, 0.33799999999999997, 0.46399999999999997, 0.53599999999999992, 0.62399999999999989, 0.66399999999999992, 0.68999999999999995, 0.71399999999999997, 0.73199999999999998, 0.754, 0.76600000000000001, 0.78800000000000003, 0.80400000000000005, 0.80800000000000005, 0.82200000000000006, 0.82600000000000007, 0.83400000000000007, 0.83600000000000008, 0.84400000000000008, 0.84600000000000009, 0.84800000000000009, 0.85000000000000009, 0.85400000000000009, 0.85400000000000009, 0.85400000000000009, 0.8580000000000001, 0.8640000000000001, 0.8660000000000001, 0.8680000000000001, 0.87600000000000011, 0.87600000000000011, 0.87600000000000011, 0.87800000000000011, 0.88000000000000012, 0.88400000000000012, 0.88400000000000012, 0.88400000000000012, 0.88400000000000012, 0.88400000000000012, 0.88600000000000012, 0.88800000000000012, 0.89000000000000012, 0.89000000000000012, 0.89000000000000012, 0.89000000000000012, 0.89000000000000012, 0.89000000000000012, 0.89000000000000012, 0.89000000000000
# ...

# %%
i=0
j=0
I=0
p=.9
s=0
while s<p:
    s=s+values[j]
    j=j+1
print 'testing. stop when',j,'vertices remained to guarantee p>=',p

while values2[i]<p:
    i=i+1

print 'stop when',i,'vertices remained to guarantee p>=',p

print 'this is ok because of the indexes'
# Out:
# testing. stop when 55 vertices remained to guarantee p>= 0.9
# stop when 54 vertices remained to guarantee p>= 0.9
# this is ok because of the indexes

# %% [markdown]
# ### Histogram 5000 2

# %%
results_cs2_5000= open("sim500n5000.txt").read().split()
results_cs2_5000=[int(i) for i in results_cs2_5000]

# %%
# %matplotlib inline
values5000, bins, _ =plt.hist(results_cs2_5000, bins=range(0,5000),normed=True)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
values=list(values5000)
values2=list(values5000)
for i in range(0,len(values)):
    values2[i]=sum(values[:i+1])

# %matplotlib inline
plt.bar(range(len(values)), values2,1)
plt.ylabel('');
plt.xlabel('size of V when 0 is removed')

# %%
print len(values)
print len(bins)
# Out:
# 4999
# 5000

# %%
s=0
for i in values:
    s=s+i
print s
# Out:
# 1.0

# %%
print values2
# Out:
# [0.0, 0.17599999999999999, 0.32799999999999996, 0.43999999999999995, 0.53999999999999992, 0.61799999999999988, 0.66199999999999992, 0.69399999999999995, 0.72999999999999998, 0.748, 0.76800000000000002, 0.77200000000000002, 0.78200000000000003, 0.79600000000000004, 0.80400000000000005, 0.82000000000000006, 0.83200000000000007, 0.84000000000000008, 0.84200000000000008, 0.84400000000000008, 0.85000000000000009, 0.85200000000000009, 0.85600000000000009, 0.8600000000000001, 0.8600000000000001, 0.8640000000000001, 0.8660000000000001, 0.8680000000000001, 0.87000000000000011, 0.87600000000000011, 0.87800000000000011, 0.87800000000000011, 0.87800000000000011, 0.88000000000000012, 0.88200000000000012, 0.88200000000000012, 0.88400000000000012, 0.88400000000000012, 0.88400000000000012, 0.88600000000000012, 0.88600000000000012, 0.89600000000000013, 0.89800000000000013, 0.89800000000000013, 0.90000000000000013, 0.90000000000000013, 0.90200000000000014, 0.90200000000000014, 0.90400000000000014, 0.9
# ...

# %%
i=0
j=0
I=0
p=.9
s=0
while s<p:
    s=s+values[j]
    j=j+1
print 'testing. stop when',j,'vertices remained to guarantee p>=',p

while values2[i]<p:
    i=i+1

print 'stop when',i,'vertices remained to guarantee p>=',p

print 'this is ok because of the indexes'
# Out:
# testing. stop when 45 vertices remained to guarantee p>= 0.9
# stop when 44 vertices remained to guarantee p>= 0.9
# this is ok because of the indexes

# %% [markdown]
# This is done only to compare the times spent by both versions of the algorithm RL **(This is not working yet)**

# %%
resultsRL_csv1={} #This dict contains all the vrtices found by the rl estimator for different graph sizes
values_rl_csv1={} #This dict is created from resultsDC
results_rl_csv1_time={}

# %%
graph_size=[100,200,300,400,500]


for N in graph_size:
    results_rl_csv1=[]
    start_time=time.time()
    for i in range(0,500):
        ba=nx.barabasi_albert_graph(N,1)
        rl_cs=rem_cs(ba)
        results_rl_csv1.append([N,rl_cs])
    final_time= -start_time +time.time()
    results_rl_csv1_time[str(N)]=final_time
    
    resultsRL_csv1[str(N)]=[i[1] for i in results_rl_csv1 ]
    # %matplotlib inline
    values, bins, _ =plt.hist(resultsRL_csv1[str(N)], bins=range(0,N),color='m',normed=True)
    values_rl_csv1[str(N)]=list(values)
    plt.ylabel('');
    plt.xlabel('cc center')
    print N
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-18-0dbd107bd871> in <module>()
#      14     resultsRL_csv1[str(N)]=[i[1] for i in results_rl_csv1 ]
#      15     get_ipython().magic(u'matplotlib inline')
# ---> 16     values, bins, _ =plt.hist(resultsRL_csv1[str(N)], bins=range(0,N),color='m',normed=True)
#      17     values_rl_csv1[str(N)]=list(values)
#      18     plt.ylabel('');
#
# /home/diego/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    3079                       histtype=histtype, align=align, orientation=orientation,
#    3080                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3081                       stacked=stacked, data=data, **kwargs)
#    3082     finally:
#    3083         ax._hold = washold
#
# ...

# %% [markdown]
# Results for both methods

# %% [markdown]
# Comparing the times for each version

# %%
plt.plot(range(100,500,100),V,'ro-',label="v=1")
plt.plot(range(100,1100,100),V2,'bo-',label="v=2")
plt.xlabel('size of BA (sim=500)')
plt.ylabel('time in secs')
plt.legend()
plt.show()
