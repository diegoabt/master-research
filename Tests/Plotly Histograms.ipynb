# %%
import time
import networkx as nx
import powerlaw
import plotly.plotly as py
# %run 'Removing-leaves estimator .ipynb'

# %%
import numpy as np
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot
print (__version__) # requires version >= 1.9.0

#Always run this the command before at the start of notebook
init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
# 2.2.2
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
resultsRL_cs={} #This dict contains all the vrtices found by the rl estimator for different graph sizes
values_rl={} #This dict is created from resultsDC
results_rl_time={}

# %%
#graph_size=[100,200,300,400,500,600,700,800,900,1000,1500,2000,2500,3000,4000,5000,10000]:


for N in [100,200,300,400,500,1000,1500,2000]:
    results_rl_cs=[]
    start_time=time.time()
    for i in range(0,500):
        ba=nx.barabasi_albert_graph(N,1)
        rl_cs=rem_cs2(ba)
        results_rl_cs.append([N,rl_cs])
    final_time= -start_time +time.time()
    results_rl_time[str(N)]=final_time
    
    resultsRL_cs[str(N)]=[i[1] for i in results_rl_cs ]
    #%matplotlib inline
    #values, bins, _ =plt.hist(resultsRL_cs[str(N)], bins=range(0,N),color='m',normed=True)
    #values_rl_cs[str(N)]=list(values)
    #plt.ylabel('');
    #plt.xlabel('cc center')
    print N
# Out:
# 100
# 200
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-4-db48da74b914> in <module>()
#       7     for i in range(0,500):
#       8         ba=nx.barabasi_albert_graph(N,1)
# ----> 9         rl_cs=rem_cs2(ba)
#      10         results_rl_cs.append([N,rl_cs])
#      11     final_time= -start_time +time.time()
#
# <ipython-input-1-d51fa6f4a439> in rem_cs2(G)
#       7     for i in graph_nodes:
#       8         graph_dict[str(i)]={}
# ----> 9         graph[str(i)]=G.degree(i)
#      10         graph_dict[str(i)]=list(G.neighbors(i))
#      11     while n>1:
#
# KeyboardInterrupt:

# %%
#SIMPLEST HISTOGRAM
x = resultsRL_cs['100']
data = go.Histogram(x=x,
                     xbins=dict(
        start=0,
        end=100,
        size=1.
    ))

iplot([data], filename='normalized histogram')
# Out:
# <div id="34658e3f-e3b3-437c-b64f-a03878db9a7e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("34658e3f-e3b3-437c-b64f-a03878db9a7e", [{"x": [1, 1, 44, 82, 5, 1, 3, 1, 3, 2, 7, 3, 5, 2, 33, 15, 15, 3, 5, 73, 9, 4, 4, 1, 28, 5, 6, 1, 2, 2, 3, 2, 25, 86, 5, 2, 2, 2, 2, 4, 13, 2, 3, 10, 2, 10, 36, 11, 4, 4, 2, 7, 1, 3, 2, 1, 54, 20, 2, 99, 17, 2, 6, 3, 4, 1, 2, 8, 1, 52, 3, 2, 18, 3, 23, 13, 1, 4, 6, 6, 11, 1, 1, 1, 4, 2, 2, 1, 3, 4, 3, 35, 2, 20, 2, 2, 3, 26, 3, 2, 8, 1, 2, 4, 3, 59, 2, 3, 53, 1, 2, 35, 2, 3, 32, 3, 3, 6, 17, 2, 4, 5, 1, 3, 75, 10, 3, 72, 2, 1, 21, 1, 20, 7, 8, 4, 5, 3, 27, 9, 9, 3, 1, 3, 16, 1, 5, 58, 2, 1, 6, 3, 8, 7, 1, 3, 1, 5, 1, 2, 3, 2, 2, 2, 3, 5, 28, 63, 5, 5, 19, 10, 2, 3, 1, 2, 5, 2, 18, 7, 2, 83, 1, 3, 4, 19, 2, 4, 2, 7, 2, 3, 2, 9, 7, 2, 1, 1, 11, 1, 3, 1, 1, 77, 71, 6, 
# ...

# %%
size={}

# %%
#CUMMULATIVE HISTOGRAM 100

x=resultsRL_cs['100']
data = [go.Histogram(x=x,
                     xbins=dict(
        start=0,
        end=100,
        size=1.
    ),
                     histnorm='probability',
                     cumulative=dict(enabled=True))]

iplot(data, filename='cumulative histogram')

bins = np.arange(0,100)
values, base = np.histogram(resultsRL_cs['100'], bins=bins, density=1)
for i in range(1,100):
    S=np.sum(values[:i])
    print S
    if S>0.8:
        print 'i!=',i
        size['100']=i
        break
# Out:
# <div id="8f9c1187-7543-406a-a4a3-d120ecb8f999" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8f9c1187-7543-406a-a4a3-d120ecb8f999", [{"x": [33, 3, 9, 7, 2, 1, 5, 6, 2, 2, 2, 4, 90, 87, 5, 1, 3, 1, 2, 2, 3, 4, 11, 16, 1, 88, 1, 6, 3, 1, 21, 3, 60, 1, 2, 3, 75, 1, 4, 2, 2, 69, 2, 1, 3, 1, 1, 100, 7, 2, 5, 12, 1, 6, 2, 4, 5, 15, 4, 2, 8, 1, 29, 3, 5, 51, 5, 4, 3, 1, 4, 3, 3, 1, 3, 12, 37, 9, 2, 5, 1, 2, 5, 3, 2, 8, 3, 2, 4, 2, 64, 7, 2, 3, 21, 3, 1, 7, 3, 1, 4, 4, 3, 3, 2, 1, 2, 2, 1, 11, 8, 6, 2, 9, 6, 3, 5, 9, 8, 90, 9, 4, 2, 8, 3, 1, 1, 6, 2, 19, 2, 1, 2, 25, 59, 1, 10, 3, 5, 1, 1, 1, 6, 29, 50, 2, 1, 1, 3, 1, 3, 4, 11, 2, 1, 2, 1, 5, 25, 5, 8, 2, 8, 6, 2, 44, 3, 3, 4, 6, 1, 3, 15, 5, 3, 12, 6, 5, 1, 5, 56, 3, 1, 1, 3, 15, 8, 7, 1, 94, 2, 3, 2, 3, 8, 3, 7, 4, 1, 3, 3, 1, 4, 1, 6, 27, 1, 2, 1, 1, 
# ...

# %%
bins = np.arange(0,100)
values, base = np.histogram(resultsRL_cs['100'], bins=bins, density=1)

print values
# Out:
# [ 0.     0.176  0.156  0.152  0.09   0.068  0.03   0.04   0.022  0.034
#   0.016  0.016  0.01   0.008  0.02   0.006  0.012  0.006  0.008  0.002
#   0.002  0.004  0.002  0.002  0.008  0.006  0.004  0.002  0.002  0.002
#   0.004  0.002  0.002  0.002  0.     0.     0.004  0.002  0.002  0.002  0.
#   0.004  0.     0.002  0.002  0.     0.     0.004  0.004  0.     0.     0.
#   0.     0.002  0.002  0.004  0.     0.002  0.004  0.     0.     0.004  0.
#   0.     0.004  0.     0.002  0.002  0.     0.002  0.     0.002  0.004  0.
#   0.     0.002  0.004  0.002  0.     0.002  0.002  0.     0.     0.     0.
#   0.002  0.002  0.     0.     0.     0.     0.002  0.     0.002  0.     0.002
#   0.002  0.     0.   ]

# %%
np.all(np.diff(base)==1)
# Out:
# True

# %%
np.sum(values)
# Out:
# 1.0

# %%
for i in range(1,100):
    S=np.sum(values[:i])
    print S
    if S>0.8:
        print 'i!=',i
        break
# Out:
# 0.0
# 0.144
# 0.32
# 0.526
# 0.596
# 0.64
# 0.682
# 0.71
# 0.734
# 0.756
# 0.778
# 0.794
# 0.804
# i!= 13

# %%
#CUMMULATIVE HISTOGRAM 200

x=resultsRL_cs['200']
data = [go.Histogram(x=x,
                     xbins=dict(
        start=0,
        end=200,
        size=1.
    ),
                     histnorm='probability',
                     cumulative=dict(enabled=True))]

iplot(data, filename='cumulative histogram')

bins = np.arange(0,200)
values, base = np.histogram(resultsRL_cs['200'], bins=bins, density=1)
for i in range(1,200):
    S=np.sum(values[:i])
    print S
    if S>0.8:
        print 'i!=',i
        size['200']=i
        break
# Out:
# <div id="10440ef3-01c9-4894-a731-96f12b135d4e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("10440ef3-01c9-4894-a731-96f12b135d4e", [{"x": [2, 1, 5, 10, 4, 1, 4, 1, 12, 4, 1, 3, 2, 33, 3, 32, 2, 1, 1, 39, 41, 4, 2, 17, 5, 9, 1, 117, 7, 4, 2, 2, 2, 7, 30, 1, 1, 1, 3, 1, 3, 50, 20, 8, 3, 7, 3, 1, 2, 2, 4, 3, 53, 5, 2, 3, 19, 25, 45, 7, 41, 7, 1, 5, 11, 53, 1, 2, 107, 159, 3, 77, 1, 48, 5, 4, 1, 3, 2, 5, 2, 4, 3, 10, 12, 2, 9, 1, 1, 6, 15, 3, 2, 5, 3, 2, 172, 2, 112, 4, 1, 1, 6, 4, 1, 3, 5, 3, 1, 44, 17, 8, 1, 2, 2, 56, 56, 1, 2, 1, 1, 2, 2, 2, 8, 5, 3, 7, 2, 4, 1, 3, 2, 47, 12, 2, 12, 8, 1, 18, 9, 3, 3, 3, 4, 110, 2, 108, 1, 4, 3, 3, 2, 19, 2, 2, 5, 2, 26, 4, 2, 2, 12, 5, 8, 5, 10, 3, 4, 11, 3, 4, 10, 17, 1, 42, 7, 1, 19, 11, 3, 16, 3, 1, 24, 25, 3, 6, 5, 8, 4, 2, 1, 2, 10, 1, 1, 1, 1, 2, 2, 1, 3, 
# ...

# %%
#CUMMULATIVE HISTOGRAM 200

x=resultsRL_cs['300']
data = [go.Histogram(x=x,
                     xbins=dict(
        start=0,
        end=300,
        size=1.
    ),
                     histnorm='probability',
                     cumulative=dict(enabled=True))]

iplot(data, filename='cumulative histogram')

bins = np.arange(0,300)
values, base = np.histogram(resultsRL_cs['300'], bins=bins, density=1)
for i in range(1,300):
    S=np.sum(values[:i])
    print S
    if S>0.8:
        print 'i!=',i
        size['300']=i
        break
# Out:
# <div id="d1a02eff-8bc1-42da-89ab-80b104f5ba66" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d1a02eff-8bc1-42da-89ab-80b104f5ba66", [{"x": [2, 4, 30, 7, 1, 80, 2, 1, 6, 1, 2, 2, 3, 152, 6, 20, 3, 5, 6, 5, 3, 5, 32, 4, 2, 2, 33, 4, 3, 50, 54, 35, 258, 5, 1, 6, 129, 2, 8, 7, 1, 8, 97, 1, 196, 1, 123, 1, 3, 3, 3, 1, 2, 1, 2, 3, 1, 15, 7, 2, 144, 2, 4, 3, 236, 4, 7, 6, 1, 10, 24, 4, 6, 6, 2, 5, 30, 3, 3, 3, 1, 2, 1, 4, 2, 1, 3, 4, 1, 2, 2, 3, 2, 1, 3, 3, 2, 150, 4, 24, 15, 2, 2, 16, 1, 11, 3, 20, 2, 1, 3, 2, 2, 1, 3, 91, 86, 6, 26, 1, 3, 2, 3, 1, 6, 20, 4, 6, 14, 3, 3, 2, 9, 15, 98, 4, 4, 5, 1, 4, 100, 43, 85, 1, 11, 2, 2, 3, 2, 35, 5, 9, 113, 1, 2, 7, 69, 2, 12, 3, 1, 90, 13, 9, 6, 6, 7, 1, 10, 1, 2, 1, 26, 105, 4, 6, 2, 5, 4, 1, 3, 1, 7, 2, 3, 3, 5, 5, 2, 1, 233, 2, 2, 3, 25, 1, 11, 28, 4, 4, 8, 2,
# ...

# %%
#CUMMULATIVE HISTOGRAM 400
label=400
x=resultsRL_cs[str(label)]
data = [go.Histogram(x=x,
                     xbins=dict(
        start=0,
        end=label,
        size=1.
    ),
                     histnorm='probability',
                     cumulative=dict(enabled=True))]

iplot(data, filename='cumulative histogram')

bins = np.arange(0,label)
values, base = np.histogram(resultsRL_cs[str(label)], bins=bins, density=1)
for i in range(1,label):
    S=np.sum(values[:i])
    print S
    if S>0.8:
        print 'i!=',i
        size[str(label)]=i
        break
# Out:
# <div id="ed67d2f6-637f-4c42-ae4d-95480d3fc992" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ed67d2f6-637f-4c42-ae4d-95480d3fc992", [{"x": [4, 1, 5, 2, 6, 2, 3, 8, 2, 5, 24, 1, 4, 1, 1, 6, 6, 322, 6, 3, 3, 1, 2, 15, 5, 2, 3, 16, 1, 1, 3, 5, 278, 1, 204, 88, 2, 1, 7, 5, 1, 1, 7, 2, 78, 9, 1, 2, 2, 14, 2, 1, 5, 2, 1, 3, 1, 4, 1, 20, 2, 212, 5, 2, 15, 3, 3, 5, 8, 2, 2, 1, 2, 20, 34, 142, 2, 1, 2, 2, 4, 69, 1, 2, 3, 2, 4, 2, 10, 2, 26, 3, 1, 14, 3, 4, 1, 9, 1, 4, 2, 1, 29, 6, 1, 5, 13, 4, 5, 312, 4, 5, 12, 6, 17, 2, 2, 1, 2, 3, 4, 4, 2, 16, 1, 4, 42, 1, 3, 4, 4, 7, 14, 6, 2, 2, 4, 1, 6, 41, 5, 378, 3, 1, 11, 9, 1, 5, 2, 2, 4, 4, 2, 2, 2, 4, 2, 1, 1, 1, 16, 2, 68, 2, 2, 376, 3, 3, 11, 1, 30, 4, 4, 17, 2, 4, 1, 1, 10, 2, 2, 4, 1, 221, 14, 8, 4, 1, 31, 2, 4, 20, 2, 10, 6, 3, 2, 3, 4, 3, 8, 2, 4, 3, 1, 5
# ...

# %%
#CUMMULATIVE HISTOGRAM 400
label=500
x=resultsRL_cs[str(label)]
data = [go.Histogram(x=x,
                     xbins=dict(
        start=0,
        end=label,
        size=1.
    ),
                     histnorm='probability',
                     cumulative=dict(enabled=True))]

iplot(data, filename='cumulative histogram')

bins = np.arange(0,label)
values, base = np.histogram(resultsRL_cs[str(label)], bins=bins, density=1)
for i in range(1,label):
    S=np.sum(values[:i])
    print S
    if S>0.8:
        print 'i!=',i
        size[str(label)]=i
        break
# Out:
# <div id="5c838b09-371b-4f13-a451-d56ab01009a7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5c838b09-371b-4f13-a451-d56ab01009a7", [{"x": [9, 1, 157, 42, 2, 2, 1, 1, 2, 21, 2, 2, 1, 3, 3, 2, 2, 2, 15, 20, 3, 3, 3, 20, 72, 1, 20, 11, 3, 3, 18, 6, 2, 4, 318, 5, 22, 7, 3, 34, 84, 2, 50, 1, 277, 31, 6, 6, 3, 2, 17, 6, 2, 3, 1, 5, 4, 4, 2, 8, 1, 5, 5, 9, 3, 1, 21, 77, 6, 8, 2, 3, 66, 1, 2, 2, 486, 8, 4, 2, 3, 38, 5, 10, 7, 2, 17, 51, 5, 2, 1, 18, 8, 1, 1, 4, 4, 8, 1, 5, 6, 9, 2, 3, 2, 4, 6, 1, 1, 6, 3, 2, 1, 6, 1, 8, 6, 2, 1, 1, 2, 3, 4, 1, 21, 4, 11, 12, 2, 3, 2, 1, 251, 1, 3, 3, 414, 1, 3, 25, 2, 7, 4, 2, 3, 5, 92, 3, 110, 10, 1, 1, 1, 90, 4, 31, 3, 1, 29, 3, 4, 5, 13, 3, 4, 2, 20, 2, 8, 5, 3, 1, 6, 138, 3, 4, 8, 4, 2, 3, 3, 22, 19, 2, 1, 7, 6, 3, 123, 3, 1, 8, 33, 5, 3, 7, 36, 15, 14, 4, 2, 36, 3,
# ...

# %%
#CUMMULATIVE HISTOGRAM 400
label=1000
x=resultsRL_cs[str(label)]
data = [go.Histogram(x=x,
                     xbins=dict(
        start=0,
        end=label,
        size=1.
    ),
                     histnorm='probability',
                     cumulative=dict(enabled=True))]

iplot(data, filename='cumulative histogram')

bins = np.arange(0,label)
values, base = np.histogram(resultsRL_cs[str(label)], bins=bins, density=1)
for i in range(1,label):
    S=np.sum(values[:i])
    print S
    if S>0.8:
        print 'i!=',i
        size[str(label)]=i
        break
# Out:
# <div id="dbd3feb5-2853-4d6c-b93b-3f3b45b79363" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dbd3feb5-2853-4d6c-b93b-3f3b45b79363", [{"x": [4, 2, 1, 118, 7, 5, 39, 16, 2, 7, 5, 9, 2, 2, 3, 1, 4, 2, 92, 2, 46, 5, 25, 3, 11, 7, 679, 2, 1, 70, 9, 6, 2, 5, 9, 15, 93, 1, 22, 3, 361, 2, 2, 9, 4, 12, 20, 4, 3, 2, 4, 1, 4, 1, 1, 6, 20, 174, 3, 6, 3, 1, 1, 2, 1, 1, 2, 2, 2, 3, 5, 8, 3, 3, 2, 14, 2, 11, 8, 8, 2, 2, 1, 2, 2, 6, 4, 2, 1, 2, 7, 5, 4, 4, 4, 1, 2, 3, 10, 1, 1, 17, 26, 5, 8, 2, 4, 97, 2, 9, 13, 3, 3, 5, 2, 13, 7, 12, 6, 5, 6, 1, 4, 10, 1, 10, 6, 26, 4, 120, 5, 1, 1, 2, 118, 17, 3, 297, 1, 1, 2, 2, 3, 2, 2, 7, 9, 3, 5, 2, 194, 2, 4, 10, 29, 8, 4, 4, 864, 3, 45, 5, 1, 4, 7, 3, 39, 3, 1, 1, 4, 30, 16, 85, 7, 2, 5, 8, 4, 2, 1, 1, 4, 10, 1, 2, 1, 5, 5, 1, 130, 3, 5, 67, 2, 43, 2, 752, 2, 2, 4, 266, 6
# ...

# %%
#CUMMULATIVE HISTOGRAM 400
label=1500
x=resultsRL_cs[str(label)]
data = [go.Histogram(x=x,
                     xbins=dict(
        start=0,
        end=label,
        size=1.
    ),
                     histnorm='probability',
                     cumulative=dict(enabled=True))]

iplot(data, filename='cumulative histogram')

bins = np.arange(0,label)
values, base = np.histogram(resultsRL_cs[str(label)], bins=bins, density=1)
for i in range(1,label):
    S=np.sum(values[:i])
    print S
    if S>0.8:
        print 'i!=',i
        size[str(label)]=i
        break
# Out:
# <div id="c6741133-9351-458b-849c-353e09060156" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c6741133-9351-458b-849c-353e09060156", [{"x": [2, 1, 3, 8, 47, 1, 2, 12, 13, 3, 9, 14, 49, 24, 2, 2, 2, 6, 4, 1, 3, 5, 2, 7, 5, 3, 6, 9, 1, 2, 2, 3, 18, 3, 2, 2, 5, 3, 183, 2, 1, 3, 5, 4, 3, 3, 7, 3, 7, 3, 6, 3, 2, 7, 32, 3, 1, 8, 11, 299, 28, 3, 1, 4, 27, 1, 14, 5, 2, 9, 1, 2, 15, 1, 2, 16, 2, 3, 2, 150, 1, 6, 9, 1, 3, 330, 9, 1, 125, 18, 8, 4, 2, 4, 14, 5, 20, 15, 2, 1, 7, 3, 54, 9, 11, 4, 1, 42, 1, 1, 49, 5, 14, 2, 2, 3, 8, 2, 3, 10, 4, 11, 2, 10, 1, 1, 21, 1, 30, 10, 1, 4, 3, 3, 2, 59, 1, 5, 16, 1, 18, 36, 7, 54, 15, 1, 3, 66, 1, 3, 891, 5, 1, 2, 28, 1, 11, 2, 3, 3, 2, 2, 1, 1, 2, 6, 2, 4, 1, 4, 350, 24, 1, 1, 4, 485, 5, 49, 5, 18, 3, 2, 3, 3, 3, 2, 1, 4, 3, 1, 1, 881, 7, 5, 2, 4, 1, 3, 1, 5, 1, 3, 13
# ...

# %%
#CUMMULATIVE HISTOGRAM 400
label=2000
x=resultsRL_cs[str(label)]
data = [go.Histogram(x=x,
                     xbins=dict(
        start=0,
        end=label,
        size=1.
    ),
                     histnorm='probability',
                     cumulative=dict(enabled=True))]

iplot(data, filename='cumulative histogram')

bins = np.arange(0,label)
values, base = np.histogram(resultsRL_cs[str(label)], bins=bins, density=1)
for i in range(1,label):
    S=np.sum(values[:i])
    print S
    if S>0.8:
        print 'i!=',i
        size[str(label)]=i
        break
# Out:
# <div id="0b75e9ad-eaed-49ec-bce7-f2b382064e58" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0b75e9ad-eaed-49ec-bce7-f2b382064e58", [{"x": [63, 2, 38, 2, 1, 2, 1, 7, 10, 5, 2, 24, 1, 42, 1, 5, 2, 25, 346, 70, 8, 2, 4, 27, 2, 3, 23, 4, 4, 70, 3, 47, 1, 33, 9, 7, 4, 29, 2, 5, 14, 1, 3, 2, 7, 1, 2, 5, 4, 1, 1, 60, 238, 5, 3, 25, 5, 37, 1872, 2, 2, 3, 5, 1, 3, 1, 5, 4, 3, 43, 5, 4, 4, 1, 18, 3, 3, 3, 1, 2, 1, 2, 10, 991, 8, 1, 1, 1, 3, 3, 1, 1, 2, 24, 2, 1, 42, 3, 2, 2, 3, 11, 4, 1, 2, 16, 7, 2, 477, 49, 5, 3, 2, 4, 2, 4, 2, 1, 3, 2, 1, 8, 9, 2, 5, 3, 4, 346, 3, 3, 2, 1, 7, 8, 4, 2, 3, 1, 3, 9, 4, 3, 13, 1, 7, 1977, 8, 2, 304, 40, 7, 1, 1, 2, 4, 1, 31, 2, 3, 5, 1, 11, 12, 3, 4, 4, 5, 2, 2, 3, 9, 1, 6, 6, 39, 2, 1, 7, 2, 5, 2, 6, 2, 3, 2, 2, 2, 1, 9, 9, 1, 1, 5, 1, 2, 6, 1, 30, 30, 3, 51, 11, 4, 7, 23
# ...
