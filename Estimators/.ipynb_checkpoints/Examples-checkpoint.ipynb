# %% [markdown]
# ### Examples

# %%
# %run 'Removing-leaves estimator .ipynb'

# %%
ba=nx.barabasi_albert_graph(35,1) #IMPORTANT PART! second input must be 1
nx.draw_networkx(ba, edge_color='k', with_labels=True, alpha=.4, linewidths=0)
plt.axis('off')
plt.show()
print 'Degrees--------------'
degree_c = nx.degree_centrality(ba)
print degree_c
print '\nMaximum value (2nd entry)---------'
print max(degree_c.iteritems(), key=operator.itemgetter(1))
# Out:
# Degrees--------------
# {0: 0.14705882352941177, 1: 0.4411764705882353, 2: 0.029411764705882353, 3: 0.029411764705882353, 4: 0.058823529411764705, 5: 0.029411764705882353, 6: 0.029411764705882353, 7: 0.11764705882352941, 8: 0.058823529411764705, 9: 0.029411764705882353, 10: 0.058823529411764705, 11: 0.029411764705882353, 12: 0.058823529411764705, 13: 0.058823529411764705, 14: 0.058823529411764705, 15: 0.029411764705882353, 16: 0.058823529411764705, 17: 0.08823529411764705, 18: 0.029411764705882353, 19: 0.058823529411764705, 20: 0.029411764705882353, 21: 0.029411764705882353, 22: 0.029411764705882353, 23: 0.029411764705882353, 24: 0.029411764705882353, 25: 0.058823529411764705, 26: 0.029411764705882353, 27: 0.058823529411764705, 28: 0.029411764705882353, 29: 0.029411764705882353, 30: 0.029411764705882353, 31: 0.029411764705882353, 32: 0.029411764705882353, 33: 0.029411764705882353, 34: 0.029411764705882353}
#
# Maximum value (2nd entry)---------
# (1, 0.4411764705882353)

# %%
rem_plot(ba)
# Out:
# [(2, 1), (3, 1), (5, 1), (6, 1), (9, 1), (11, 1), (15, 1), (18, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (26, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 1), (33, 1), (34, 1), (4, 2), (8, 2), (10, 2), (12, 2), (13, 2), (14, 2), (16, 2), (19, 2), (25, 2), (27, 2), (17, 3), (7, 4), (0, 5), (1, 15)]
# 1
# [2, 3, 5, 6, 9, 11, 15, 18, 20, 21, 22, 23, 24, 26, 28, 29, 30, 31, 32, 33, 34]
# min vert 9
# [(2, 1), (3, 1), (5, 1), (6, 1), (11, 1), (15, 1), (18, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (26, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 1), (33, 1), (34, 1), (4, 2), (8, 2), (10, 2), (12, 2), (13, 2), (14, 2), (16, 2), (19, 2), (25, 2), (27, 2), (17, 3), (7, 4), (0, 5), (1, 14)]
# 1
# [2, 3, 5, 6, 11, 15, 18, 20, 21, 22, 23, 24, 26, 28, 29, 30, 31, 32, 33, 34]
# min vert 26
# ...

# %%
ba=nx.barabasi_albert_graph(10,1)
nx.draw(ba,with_labels=True)
plt.show()

# %%
rem(ba)
# Out:
# [(0, 1), (2, 1), (4, 1), (6, 1), (7, 1), (8, 1), (9, 1), (3, 2), (5, 4), (1, 5)]
# True
# [(0, 1), (2, 1), (4, 1), (7, 1), (8, 1), (9, 1), (3, 2), (1, 4), (5, 4)]
# True
# [(0, 1), (2, 1), (4, 1), (7, 1), (8, 1), (3, 2), (5, 3), (1, 4)]
# True
# [(0, 1), (2, 1), (7, 1), (8, 1), (3, 2), (1, 3), (5, 3)]
# True
# [(0, 1), (2, 1), (8, 1), (3, 2), (5, 2), (1, 3)]
# True
# [(2, 1), (8, 1), (1, 2), (3, 2), (5, 2)]
# True
# [(1, 1), (8, 1), (3, 2), (5, 2)]
# True
# [(3, 1), (8, 1), (5, 2)]
# True
# [(3, 1), (5, 1)]
# True
# 3
